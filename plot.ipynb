# %%
import torch

result = torch.load('result_1.pt')
print(result.shape)

aux = result.shape[2]//3
theta = result[:, 0, :aux]
v = result[:, 0, aux:2*aux]
print(v.shape)
v_norm = torch.norm(v, dim=1)

import matplotlib.pyplot as plt

plt.plot(v[:, 10].numpy())
plt.xlabel('Index')
plt.ylabel('Norm of v')
plt.title('Plot of v_norm')
plt.show()
# Out:
# torch.Size([11, 1, 180])
# torch.Size([11, 60])

# %%
# Carica il file all_grad_1.pt
all_grad_1 = torch.load('all_grad_1.pt')

print(all_grad_1.shape)

# Calcola la norma lungo dim=0
norm_all_grad_1 = torch.norm(all_grad_1, dim=0)

# Plotta la norma
plt.plot(norm_all_grad_1.numpy())
plt.xlabel('Index')
plt.ylabel('Norm of all_grad_1')
plt.title('Plot of norm_all_grad_1')
plt.show()
# Out:
# torch.Size([169, 60])

# %%
def prova(a):
    b, c = a
    return b+c

print(prova((1, 2)))
# Out:
# 3
